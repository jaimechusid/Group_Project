# %%
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
import yfinance as yf

# %%
Soybeans=yf.Ticker("ZS=F")
Corn=yf.Ticker("ZC=F")
Wheat=yf.Ticker("ZW=F")
Cotton=yf.Ticker("CT=F")
Crude=yf.Ticker("CL=F")
USDBRL=yf.Ticker("BRL=X")
EURUSD=yf.Ticker("EURUSD=X")
IR=yf.Ticker("^TNX")

# %%
Soybeans_H=Soybeans.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"Soybeans Open","High": "Soybeans High","Low": "Soybeans Low", "Close": "Soybeans Close", "Volume" : "Soybeans Volume"})[:len(USDBRL_H)]
Corn_H=Corn.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"Corn Open","High": "Corn High","Low": "Corn Low", "Close": "Corn Close", "Volume" : "Corn Volume"})[:len(USDBRL_H)]
Wheat_H=Wheat.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"Wheat Open","High": "Wheat High","Low": "Wheat Low", "Close": "Wheat Close", "Volume" : "Wheat Volume"})[:len(USDBRL_H)]
Cotton_H=Cotton.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"Cotton Open","High": "Cotton High","Low": "Cotton Low", "Close": "Cotton Close", "Volume" : "Cotton Volume"})[:len(USDBRL_H)]
Crude_H=Crude.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"Crude Open","High": "Crude High","Low": "Crude Low", "Close": "Crude Close", "Volume" : "Crude Volume"})[:len(USDBRL_H)]
USDBRL_H=USDBRL.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"USDBRL Open","High": "USDBRL High","Low": "USDBRL Low", "Close": "USDBRL Close", "Volume" : "USDBRL Volume"})[:len(USDBRL_H)]
EURUSD_H=EURUSD.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"EURUSD Open","High": "EURUSD High","Low": "EURUSD Low", "Close": "EURUSD Close", "Volume" : "EURUSD Volume"})[:len(USDBRL_H)]
IR_H=IR.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits"], axis=1).rename(columns={"Open":"IR Open","High": "IR High","Low": "IR Low", "Close": "IR Close", "Volume" : "IR Volume"})[:len(USDBRL_H)]

# %%
#d={}
Prices = [Corn_H, Wheat_H, Cotton_H, Crude_H, USDBRL_H, EURUSD_H, IR_H]
#for price in Prices:
    #d[price]= price.history(period="Max")

# %%
#d[Corn].sort_values(by="Date", ascending=False)
#for price in Prices:
    #price.sort_values(by="Date", ascending=False)

# %%
for price in Prices:
    print (price.shape)
# Out:
# (4035, 5)
# (4035, 5)
# (4035, 5)
# (4035, 5)
# (4035, 5)
# (4035, 5)
# (4035, 5)

# %%
for price in Prices:
    Soybeans_H=Soybeans_H.merge(price, on="Date")

# %%
AllData=Soybeans_H
AllData
# Out:
#             Soybeans Open  Soybeans High  Soybeans Low  Soybeans Close  \
# Date
# 2021-03-03        1415.00        1417.75       1397.50         1399.00
# 2021-03-02        1395.00        1416.00       1383.50         1414.00
# 2021-03-01        1415.75        1422.00       1392.00         1392.50
# 2021-02-26        1404.00        1408.25       1380.00         1405.25
# 2021-02-25        1423.50        1443.00       1391.75         1406.00
# ...                   ...            ...           ...             ...
# 2006-03-30         581.50         583.50        581.00          587.75
# 2006-03-29         581.50         583.75        580.75          582.50
# 2006-03-28         578.75         580.75        578.00          581.50
# 2006-03-27         573.75         579.00        572.50          579.50
# 2006-03-24         575.00         577.50        575.00          573.75
#
#             Soybeans Volume  Corn Open  Corn High  Corn Low  Corn Close  \
# Date
# ...

# %%
AllData.to_csv("AllData.csv")
